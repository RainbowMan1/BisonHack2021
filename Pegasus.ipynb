# %%
from transformers import BartTokenizer, TFBartForConditionalGeneration, BartConfig
model = TFBartForConditionalGeneration.from_pretrained('facebook/bart-large')
tokenizer = BartTokenizer.from_pretrained('facebook/bart-large')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1525.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1625696184.0, style=ProgressStyle(descr…
# All model checkpoint layers were used when initializing TFBartForConditionalGeneration.
#
# All the layers of TFBartForConditionalGeneration were initialized from the model checkpoint at facebook/bart-large.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBartForConditionalGeneration for predictions without further training.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=898822.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=26.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1355863.0, style=ProgressStyle(descript…

# %%
f = open("article.txt", "r")
ARTICLE_TO_SUMMARIZE = f.read()
inputs = tokenizer([ARTICLE_TO_SUMMARIZE], max_length=1024, return_tensors='tf')

# Generate Summary
summary_ids = model.generate(inputs['input_ids'], max_length=1000, early_stopping=True)
print([tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in summary_ids])
# Out:
# ['</s>AN.ANCHORAGE, Alaska — The United States and China’s top diplomats ended a two-day round of high-level talks with no major diplomatic breakthroughs, and acknowledged that a tense relationship lies ahead for Washington and the two countries will take stock of how the Biden administration would approach diplomatic relations with Beijing.ANchorage, Alaska …息美恽网恾罩決求恭懷置拳揮汁技罯揄汄悮描揁揀揅揆提揜換揚揺揋揼揑揸揃揓揙揂揝揊揻揟揽揤揍揠握揎揯懸悯憲揪插揉揿揥揣揈揭揗揳憼拸懹汆授掄揾揦揇揨揱揘援揲憆指罪据持ष拍捯拜汀招捍拄捨汅拆抄抜折拁汜憺捏拤投揹揌揫揢揰揅�揧揔揷揞揚連把罄憄掀抛拀挍挀汛憊拣捲挂拪憚捒按捘時捻時罚憏捋捰時设担捧捌時倍時那拉报捀憓挈抎拋憛挅抁憜捊憁拓捜挃憋抪拂抹拝捙時、挊時最時間汃捓拮捁捛時,挋態捃時分捂時了憟捼挎時。挒時问憈捺挐時公司振時的罛汊捆拦捄挌曆悓抑抭時代捾時益挑捣汋時多护捿時2捉挘江拠捔時3损時4挜時5時6時7時8時9時10時11時12時13時14時15時16時17時18時20時25時21時24時26時27時1時23時30時22時28時33時34時35時36時45時']

# %%
print([tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in summary_ids])
# Out:
# ['AN.ANCHORAGE, Alaska — The United States and China’s top diplomats ended a two-day round of high-level talks with no major diplomatic breakthroughs, and acknowledged that a tense relationship lies ahead for Washington and the two countries will take stock of how the Biden administration would approach diplomatic relations with Beijing.ANchorage, Alaska …息美恽网恾罩決求恭懷置拳揮汁技罯揄汄悮描揁揀揅揆提揜換揚揺揋揼揑揸揃揓揙揂揝揊揻揟揽揤揍揠握揎揯懸悯憲揪插揉揿揥揣揈揭揗揳憼拸懹汆授掄揾揦揇揨揱揘援揲憆指罪据持ष拍捯拜汀招捍拄捨汅拆抄抜折拁汜憺捏拤投揹揌揫揢揰揅�揧揔揷揞揚連把罄憄掀抛拀挍挀汛憊拣捲挂拪憚捒按捘時捻時罚憏捋捰時设担捧捌時倍時那拉报捀憓挈抎拋憛挅抁憜捊憁拓捜挃憋抪拂抹拝捙時、挊時最時間汃捓拮捁捛時,挋態捃時分捂時了憟捼挎時。挒時问憈捺挐時公司振時的罛汊捆拦捄挌曆悓抑抭時代捾時益挑捣汋時多护捿時2捉挘江拠捔時3损時4挜時5時6時7時8時9時10時11時12時13時14時15時16時17時18時20時25時21時24時26時27時1時23時30時22時28時33時34時35時36時45時']
